# %% [markdown]
# # GERMAN CREDIT MODELING
#
# Analysis of the open source data sample: German Credit Data. It contains observations on 20 variables for 1000 bank clients. Client are rated as “good credit” (700 cases) or “bad credit” (300 cases) based on how well they repay their debts.
#
# ### Metadata as follows:
#
# <pre>Attribute 1: (qualitative)
# Status of existing checking account
# A11 : ... < 0 DM
# A12 : 0 <= ... < 200 DM
# A13 : ... >= 200 DM / salary assignments for at least 1 year
# A14 : no checking account
#
# Attribute 2: (numerical)
# Duration in month
#
# Attribute 3: (qualitative)
# Credit history
# A30 : no credits taken/ all credits paid back duly
# A31 : all credits at this bank paid back duly
# A32 : existing credits paid back duly till now
# A33 : delay in paying off in the past
# A34 : critical account/ other credits existing (not at this bank)
#
# Attribute 4: (qualitative)
# Purpose
# A40 : car (new)
# A41 : car (used)
# A42 : furniture/equipment
# A43 : radio/television
# A44 : domestic appliances
# A45 : repairs
# A46 : education
# A47 : (vacation - does not exist?)
# A48 : retraining
# A49 : business
# A410 : others
#
# Attribute 5: (numerical)
# Credit amount
#
# Attibute 6: (qualitative)
# Savings account/bonds
# A61 : ... < 100 DM
# A62 : 100 <= ... < 500 DM
# A63 : 500 <= ... < 1000 DM
# A64 : .. >= 1000 DM
# A65 : unknown/ no savings account
#
# Attribute 7: (qualitative)
# Present employment since
# A71 : unemployed
# A72 : ... < 1 year
# A73 : 1 <= ... < 4 years
# A74 : 4 <= ... < 7 years
# A75 : .. >= 7 years
#
# Attribute 8: (numerical)
# Installment rate in percentage of disposable income
#
# Attribute 9: (qualitative)
# Personal status and sex
# A91 : male : divorced/separated
# A92 : female : divorced/separated/married
# A93 : male : single
# A94 : male : married/widowed
# A95 : female : single
#
# Attribute 10: (qualitative)
# Other debtors / guarantors
# A101 : none
# A102 : co-applicant
# A103 : guarantor
#
# Attribute 11: (numerical)
# Present residence since
#
# Attribute 12: (qualitative)
# Property
# A121 : real estate
# A122 : if not A121 : building society savings agreement/ life insurance
# A123 : if not A121/A122 : car or other, not in attribute 6
# A124 : unknown / no property
#
# Attribute 13: (numerical)
# Age in years
#
# Attribute 14: (qualitative)
# Other installment plans
# A141 : bank
# A142 : stores
# A143 : none
#
# Attribute 15: (qualitative)
# Housing
# A151 : rent
# A152 : own
# A153 : for free
#
# Attribute 16: (numerical)
# Number of existing credits at this bank
#
# Attribute 17: (qualitative)
# Job
# A171 : unemployed/ unskilled - non-resident
# A172 : unskilled - resident
# A173 : skilled employee / official
# A174 : management/ self-employed/
# highly qualified employee/ officer
#
# Attribute 18: (numerical)
# Number of people being liable to provide maintenance for
#
# Attribute 19: (qualitative)
# Telephone
# A191 : none
# A192 : yes, registered under the customers name
#
# Attribute 20: (qualitative)
# foreign worker
# A201 : yes
# A202 : no
# </pre>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Metadata
md = pd.read_csv('~/Documents/My Samples/GermanCreditMetaData.csv',header=0,index_col='Code')
md['Ord Meaning'] = md.index + ' ' + md.Meaning
mdmap = md['Ord Meaning'].to_dict()

# %%
# Data
df = pd.read_csv('~/Documents/My Samples/germancredit.csv',header=0)

# %%
df.describe().transpose()
# No Missing Values
# Out:
#                count      mean          std    min     25%     50%      75%  \
# GoodCredit    1000.0     1.300     0.458487    1.0     1.0     1.0     2.00
# duration2     1000.0    20.903    12.058814    4.0    12.0    18.0    24.00
# amount5       1000.0  3271.258  2822.736876  250.0  1365.5  2319.5  3972.25
# installment8  1000.0     2.973     1.118715    1.0     2.0     3.0     4.00
# residence11   1000.0     2.845     1.103718    1.0     2.0     3.0     4.00
# age13         1000.0    35.546    11.375469   19.0    27.0    33.0    42.00
# cards16       1000.0     1.407     0.577654    1.0     1.0     1.0     2.00
# liable18      1000.0     1.155     0.362086    1.0     1.0     1.0     1.00
#
#                   max
# GoodCredit        2.0
# duration2        72.0
# amount5       18424.0
# installment8      4.0
# residence11       4.0
# age13            75.0
# cards16           4.0
# liable18          2.0

# %%
df.describe(include='O').transpose()
# No Missing Values
# Out:
#                 count unique   top freq
# checkingstatus1  1000      4   A14  394
# history3         1000      5   A32  530
# purpose4         1000     10   A43  280
# savings6         1000      5   A61  603
# employ7          1000      5   A73  339
# status9          1000      4   A93  548
# others10         1000      3  A101  907
# property12       1000      4  A123  332
# otherplans14     1000      3  A143  814
# housing15        1000      3  A152  713
# job17            1000      4  A173  630
# tele19           1000      2  A191  596
# foreign20        1000      2  A201  963

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Dependent Variable
# Use Target Bad Credit (Good Credit == 2)
df['bad'] = df.pop('GoodCredit') - 1
_ = df.bad.map({1:'1 = bad', 0:'0 = good'}).value_counts().plot(kind='pie',
            title='Distribution of Bad Credit',colormap='bwr')

# %%
b = {'duration2':7,'amount5':9,'age13':11}
for col in ['duration2','amount5','age13']:
    df.boxplot(column=col,by='bad',fontsize=15)
    df.hist(column=col,by='bad',color='#267fcf',bins=b[col])

# %%
# Sparce Numerical Variables
v_sparce = ['installment8','residence11','cards16','liable18']
for col in v_sparce:
    display(pd.crosstab(df[col],df.bad).style.bar(align='zero',color='lightgreen'))
# Out:
# <style  type="text/css" >
#     #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 66.1%, transparent 66.1%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.7%, transparent 60.7%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 76.7%, transparent 76.7%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.5%, transparent 69.5%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 67.7%, transparent 67.7%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.2%, transparent 64.2%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }</style><table id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >installment8</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >102</td>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >169</td>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >112</td>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >317</td>
#                         <td id="T_4a87f1ae_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >159</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 66.3%, transparent 66.3%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.5%, transparent 64.5%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 86.5%, transparent 86.5%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 89.1%, transparent 89.1%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 68.3%, transparent 68.3%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 67.3%, transparent 67.3%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }</style><table id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >residence11</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >94</td>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >211</td>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >97</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >106</td>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >289</td>
#                         <td id="T_4a8b43c2_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >124</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 77.8%, transparent 77.8%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 73.0%, transparent 73.0%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.5%, transparent 52.5%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.5%, transparent 51.5%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 50.5%, transparent 50.5%);
#         }    #T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 50.5%, transparent 50.5%);
#         }</style><table id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >cards16</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >433</td>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >200</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >241</td>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >92</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >22</td>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_4a8e8b22_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >2</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 59.2%, transparent 59.2%);
#         }    #T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 59.1%, transparent 59.1%);
#         }</style><table id="T_4a91ee98_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >liable18</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a91ee98_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >591</td>
#                         <td id="T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >254</td>
#             </tr>
#             <tr>
#                         <th id="T_4a91ee98_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >109</td>
#                         <td id="T_4a91ee98_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >46</td>
#             </tr>
#     </tbody></table>

# %%
v_nominal = df.select_dtypes(include='O').columns        
for col in v_nominal:
    display(pd.crosstab(df[col].map(mdmap),df.bad).style.bar(align='zero',color='lightgreen'))
# Out:
# <style  type="text/css" >
#     #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 70.0%, transparent 70.0%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 73.6%, transparent 73.6%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 88.9%, transparent 88.9%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 57.0%, transparent 57.0%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 55.2%, transparent 55.2%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 67.0%, transparent 67.0%);
#         }</style><table id="T_4a9735d8_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >checkingstatus1</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a9735d8_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A11  ... < 0 DM </th>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >139</td>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >135</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9735d8_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A12  0 <= ... < 200 DM </th>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >164</td>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9735d8_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A13  ... >= 200 DM / salary assignments for at least 1 year </th>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >49</td>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9735d8_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A14  no checking account </th>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >348</td>
#                         <td id="T_4a9735d8_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >46</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.1%, transparent 52.1%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 57.4%, transparent 57.4%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.9%, transparent 52.9%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.3%, transparent 58.3%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.3%, transparent 58.3%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.3%, transparent 58.3%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.7%, transparent 83.7%);
#         }    #T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.8%, transparent 64.8%);
#         }</style><table id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >history3</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A30  no credits taken/ all credits paid back duly </th>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >15</td>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A31  all credits at this bank paid back duly </th>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >21</td>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A32  existing credits paid back duly till now </th>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >361</td>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >169</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A33  delay in paying off in the past </th>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >60</td>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febclevel0_row4" class="row_heading level0 row4" >A34  critical account/ other credits existing (not at this bank) </th>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow4_col0" class="data row4 col0" >243</td>
#                         <td id="T_4a9a9dd6_fd95_11e9_b5cd_989e6331febcrow4_col1" class="data row4 col1" >50</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.3%, transparent 83.3%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.7%, transparent 69.7%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 59.6%, transparent 59.6%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.6%, transparent 51.6%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.8%, transparent 52.8%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 78.2%, transparent 78.2%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.6%, transparent 82.6%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 84.8%, transparent 84.8%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.8%, transparent 51.8%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.2%, transparent 52.2%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 53.2%, transparent 53.2%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 54.5%, transparent 54.5%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 56.4%, transparent 56.4%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.4%, transparent 62.4%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.8%, transparent 51.8%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 50.6%, transparent 50.6%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.4%, transparent 64.4%);
#         }    #T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.1%, transparent 69.1%);
#         }</style><table id="T_4a9ef200_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >purpose4</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A40  car (new) </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >145</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >89</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A41  car (used) </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >86</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A410  others </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >7</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A42  furniture/equipment </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >123</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row4" class="row_heading level0 row4" >A43  radio/television </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow4_col0" class="data row4 col0" >218</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow4_col1" class="data row4 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row5" class="row_heading level0 row5" >A44  domestic appliances </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow5_col0" class="data row5 col0" >8</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_4a9ef200_fd95_11e9_b5cd_989e6331febclevel0_row6" class="row_heading level0 row6" >A45  repairs </th>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow6_col0" class="data row6 col0" >14</td>
#                         <td id="T_4a9ef200_fd95_11e9_b5cd_989e6331febcrow6_col1" class="data row6 col1" >8
# <style  type="text/css" >
#     #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.9%, transparent 58.9%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 57.8%, transparent 57.8%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 56.7%, transparent 56.7%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.5%, transparent 52.5%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 55.4%, transparent 55.4%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.4%, transparent 51.4%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 69.6%, transparent 69.6%);
#         }    #T_4aa29644_fd95_11e9_b5cd_989e6331febcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 57.4%, transparent 57.4%);
#         }</style><table id="T_4aa29644_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >savings6</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aa29644_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A61  ... < 100 DM </th>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >386</td>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >217</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa29644_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A62  100 <= ... < 500 DM </th>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >69</td>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa29644_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A63  500 <= ... < 1000 DM </th>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >52</td>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa29644_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A64  .. >= 1000 DM </th>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >42</td>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa29644_fd95_11e9_b5cd_989e6331febclevel0_row4" class="row_heading level0 row4" >A65  unknown/ no savings account </th>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow4_col0" class="data row4 col0" >151</td>
#                         <td id="T_4aa29644_fd95_11e9_b5cd_989e6331febcrow4_col1" class="data row4 col1" >32</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.3%, transparent 58.3%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 61.1%, transparent 61.1%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 71.7%, transparent 71.7%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 83.7%, transparent 83.7%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 78.7%, transparent 78.7%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 68.7%, transparent 68.7%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.2%, transparent 90.2%);
#         }    #T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.8%, transparent 80.8%);
#         }</style><table id="T_4aa637ae_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >employ7</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aa637ae_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A71  unemployed </th>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >39</td>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa637ae_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A72  ... < 1 year </th>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >102</td>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa637ae_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A73  1 <= ... < 4 years </th>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >235</td>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa637ae_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A74  4 <= ... < 7 years </th>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >135</td>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >39</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa637ae_fd95_11e9_b5cd_989e6331febclevel0_row4" class="row_heading level0 row4" >A75  .. >= 7 years </th>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow4_col0" class="data row4 col0" >189</td>
#                         <td id="T_4aa637ae_fd95_11e9_b5cd_989e6331febcrow4_col1" class="data row4 col1" >64</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 53.7%, transparent 53.7%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 56.8%, transparent 56.8%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 75.0%, transparent 75.0%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.3%, transparent 87.3%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.3%, transparent 58.3%);
#         }    #T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 58.6%, transparent 58.6%);
#         }</style><table id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >status9</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A91  male divorced/separated </th>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >30</td>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A92  female divorced/separated/married </th>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >201</td>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A93  male single </th>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >402</td>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >146</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A94  male married/widowed </th>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >67</td>
#                         <td id="T_4aa9c2e8_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >25</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.8%, transparent 51.8%);
#         }    #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 53.3%, transparent 53.3%);
#         }    #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 53.3%, transparent 53.3%);
#         }    #T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.8%, transparent 51.8%);
#         }</style><table id="T_4aad6a88_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >others10</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aad6a88_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A101  none </th>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >635</td>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >272</td>
#             </tr>
#             <tr>
#                         <th id="T_4aad6a88_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A102  co-applicant </th>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >23</td>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_4aad6a88_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A103  guarantor </th>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >42</td>
#                         <td id="T_4aad6a88_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >10</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 98.3%, transparent 98.3%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 79.4%, transparent 79.4%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 85.0%, transparent 85.0%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 84.8%, transparent 84.8%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 68.9%, transparent 68.9%);
#         }    #T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 82.8%, transparent 82.8%);
#         }</style><table id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >property12</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A121  real estate </th>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >222</td>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A122  if not A121 building society savings agreement/ life insurance </th>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >161</td>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A123  if not A121/A122 car or other, not in attribute 6 </th>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >230</td>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >102</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A124  unknown / no property </th>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >87</td>
#                         <td id="T_4ab0b1a2_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >67</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 56.9%, transparent 56.9%);
#         }    #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 62.7%, transparent 62.7%);
#         }    #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.4%, transparent 52.4%);
#         }    #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 54.2%, transparent 54.2%);
#         }    #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }</style><table id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >otherplans14</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A141  bank </th>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >82</td>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >57</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A142  stores </th>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >28</td>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A143  none </th>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >590</td>
#                         <td id="T_4ab3f3a8_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >224</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.3%, transparent 60.3%);
#         }    #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 68.8%, transparent 68.8%);
#         }    #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 56.1%, transparent 56.1%);
#         }    #T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 61.8%, transparent 61.8%);
#         }</style><table id="T_4ab732b6_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >housing15</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ab732b6_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A151  rent </th>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >109</td>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab732b6_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A152  own </th>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >527</td>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >186</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab732b6_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A153  for free </th>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >64</td>
#                         <td id="T_4ab732b6_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >44</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.7%, transparent 51.7%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 51.9%, transparent 51.9%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 66.2%, transparent 66.2%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 65.1%, transparent 65.1%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 60.9%, transparent 60.9%);
#         }    #T_4aba9596_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 63.7%, transparent 63.7%);
#         }</style><table id="T_4aba9596_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >job17</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aba9596_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A171  unemployed/ unskilled - non-resident </th>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >15</td>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4aba9596_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A172  unskilled - resident </th>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >144</td>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_4aba9596_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >A173  skilled employee / official </th>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >444</td>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >186</td>
#             </tr>
#             <tr>
#                         <th id="T_4aba9596_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >A174  management/ self-employed/ </th>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >97</td>
#                         <td id="T_4aba9596_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >51</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 85.6%, transparent 85.6%);
#         }    #T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 80.2%, transparent 80.2%);
#         }</style><table id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >tele19</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A191  none </th>
#                         <td id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >409</td>
#                         <td id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >187</td>
#             </tr>
#             <tr>
#                         <th id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A192  yes, registered under the customers name </th>
#                         <td id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >291</td>
#                         <td id="T_4abdf9ca_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >113</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_4ac10250_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ac10250_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4ac10250_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 52.5%, transparent 52.5%);
#         }    #T_4ac10250_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 50.7%, transparent 50.7%);
#         }</style><table id="T_4ac10250_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >foreign20</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ac10250_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >A201  yes </th>
#                         <td id="T_4ac10250_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >667</td>
#                         <td id="T_4ac10250_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >296</td>
#             </tr>
#             <tr>
#                         <th id="T_4ac10250_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >A202  no </th>
#                         <td id="T_4ac10250_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >33</td>
#                         <td id="T_4ac10250_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >4</td>
#             </tr>
#     </tbody></table>

# %%
df.shape
# Out:
# (1000, 21)

# %% [markdown]
# # Feature Engineering

# %%
# Feature Engineering
# Is there a way to recode Age?

# %%
df2 = df[['age13','bad']].copy()
df2['age_group'] = pd.cut(df.age13,[18,25,30,40,50,60,90])
age_dist = df2.groupby(['age_group','bad']).size().unstack()
age_dist.style.bar(color='lightgreen',axis=1,align='zero')
# Out:
# <style  type="text/css" >
#     #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 86.4%, transparent 86.4%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 72.2%, transparent 72.2%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 67.0%, transparent 67.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 67.1%, transparent 67.1%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 72.3%, transparent 72.3%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 64.3%, transparent 64.3%);
#         }</style><table id="T_4acc3c74_fd95_11e9_b5cd_989e6331febc" ><thead>    <tr>        <th class="index_name level0" >bad</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >age_group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row0" class="row_heading level0 row0" >(18, 25]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow0_col0" class="data row0 col0" >110</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow0_col1" class="data row0 col1" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row1" class="row_heading level0 row1" >(25, 30]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow1_col0" class="data row1 col0" >153</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow1_col1" class="data row1 col1" >68</td>
#             </tr>
#             <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row2" class="row_heading level0 row2" >(30, 40]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow2_col0" class="data row2 col0" >235</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow2_col1" class="data row2 col1" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row3" class="row_heading level0 row3" >(40, 50]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow3_col0" class="data row3 col0" >120</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow3_col1" class="data row3 col1" >41</td>
#             </tr>
#             <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row4" class="row_heading level0 row4" >(50, 60]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow4_col0" class="data row4 col0" >47</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow4_col1" class="data row4 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_4acc3c74_fd95_11e9_b5cd_989e6331febclevel0_row5" class="row_heading level0 row5" >(60, 90]</th>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow5_col0" class="data row5 col0" >35</td>
#                         <td id="T_4acc3c74_fd95_11e9_b5cd_989e6331febcrow5_col1" class="data row5 col1" >10</td>
#             </tr>
#     </tbody></table>

# %%
print('AGE DISTRIBUTION A')
_ = (age_dist[1] / age_dist.sum(axis=1)).plot.bar(color='#267fcf')
# Out:
# AGE DISTRIBUTION A

# %%
# New Feature: Age Group (Nominal)
print('AGE DISTRIBUTION B')
df['age_group'] =  pd.cut(df.age13,[18,25,30,50,60,90])
_ = df.groupby('age_group').bad.mean().plot.bar(color='#267fcf')
# Out:
# AGE DISTRIBUTION B

# %% [markdown]
# ## Predictors Treated as Nominal

# %%
v_nominal = list(df.select_dtypes(include='O').columns)
nominal = v_nominal + ['age_group'] + ['installment8','residence11','liable18']
nominal
# Out:
# ['checkingstatus1',
#  'history3',
#  'purpose4',
#  'savings6',
#  'employ7',
#  'status9',
#  'others10',
#  'property12',
#  'otherplans14',
#  'housing15',
#  'job17',
#  'tele19',
#  'foreign20',
#  'age_group',
#  'installment8',
#  'residence11',
#  'liable18']
